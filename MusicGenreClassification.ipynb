# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('Datasets/MusicGenreClassification/train.csv')
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#data.describe(include="all")
#artist_by_popularity = data.groupby('Artist Name')['Popularity'].sum()
#artist_by_popularity.describe(include="all")
data.head()
# Out:
#              Artist Name                             Track Name  Popularity  \
# 0             Bruno Mars  That's What I Like (feat. Gucci Mane)        60.0
# 1                 Boston                           Hitch a Ride        54.0
# 2          The Raincoats                     No Side to Fall In        35.0
# 3                   Deno             Lingo (feat. J.I & Chunkz)        66.0
# 4  Red Hot Chili Peppers      Nobody Weird Like Me - Remastered        53.0
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.854   0.564   1.0    -4.964     1       0.0485      0.017100
# 1         0.382   0.814   3.0    -7.230     1       0.0406      0.001100
# 2         0.434   0.614   6.0    -8.334     1       0.0525      0.486000
# 3         0.853   0.597  10.0    -6.528     0       0.0555      0.021200
# 4         0.167   0.975   2.0    -4.279     1       0.2160      0.000169
#
# ...

# %%
data.groupby(['Artist Name','Popularity']).mean()
# Out:
#                               danceability  energy  key  loudness  mode  \
# Artist Name       Popularity
# $NOT              76.0               0.841   0.545  9.0    -8.013   1.0
# $uicideboy$       79.0               0.792   0.511  2.0    -6.876   1.0
# '68               36.0               0.558   0.977  1.0    -5.082   1.0
# (Hed) P.E.        40.0               0.619   0.871  1.0    -5.214   0.0
#                   44.0               0.438   0.947  2.0    -3.481   1.0
# ...                                    ...     ...  ...       ...   ...
# מאיכו        20.0               0.782   0.518  6.0   -11.299   1.0
# מינוס אפס 17.0               0.377   0.512  3.0    -7.472   1.0
#                   19.0               0.470   0.654  NaN    -5.282   1.0
# מכלוף        42.0               0.781   0.437  2.0    -7.213   0.0
# נאדה          14.0               0.626   0.562  7.0   -10.812   0.0
#
# ...
